# %% [markdown]
# # Project Chaitanya - Google Colab Training
#
# Welcome to the Colab environment. Follow these steps to train the TinyGPT model on a free GPU.

# %%
# Step 1: Mount Google Drive
# Ensure you have uploaded the 'tiny-gpt' folder to the root of your Google Drive.
from google.colab import drive
drive.mount('/content/drive')

# %%
# Step 2: Navigate to the project directory
# %cd /content/drive/MyDrive/tiny-gpt

# %%
# Step 3: Install dependencies
# !pip install tiktoken

# %%
# Step 4: Verify GPU is active
import torch
print('GPU is active!' if torch.cuda.is_available() else 'NO GPU FOUND. Go to Runtime -> Change runtime type -> T4 GPU')

# %%
# Step 5: Run the MoE Benchmark
# This will run the experiment on the GPU much faster than your local CPU.
# !python experiments/moe_benchmark.py

# %%
# Step 6: Full Training (Optional)
# To train the full model, run this cell:
# !python train.py
